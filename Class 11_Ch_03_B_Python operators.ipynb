# %% [markdown]
# # Operators In Python

# %% [markdown]
# Operators are used to perform operrations on operands (variable or value)
#
# An operator is used to perform specific mathematical or
# logical operation on values. The values that the operator
# works on are called operands.

# %% [markdown]
# ##### Operators:
# The operators indicate what action or operation to perform.
#
# ##### Operands:
# The operands indicate what items to apply the action to.

# %% [markdown]
# ###  Python divides the operators in the following groups.

# %% [markdown]
# ### Arithmetic Operators

# %% [markdown]
# Arithmetic operators are used to perform mathematical operations like addition, subtraction, multiplication and division.

# %% [raw]
# There are 7 arithmetic operators in Python :
#
# Addition
# Subtraction
# Multiplication
# Division
# Modulus
# Exponentiation
# Floor division

# %% [markdown]
#  Addition Operator : In Python addition (+)  operator is used to add two values or variables value.
#
#  sign : +

# %%
a = 4
b = 5
sum = a + b
sum
# Out:
# 9

# %% [markdown]
# Subtraction Operator : In Python (–) is the subtraction operator. It is used to subtract the second value from the first value.

# %%
a = 4
b = 5
subtract = a-b
subtract
# Out:
# -1

# %% [markdown]
#  Multiplication Operator : In Python (*) is the multiplication operator. It is used to find the product of 2 values.

# %%
a = 4
b = 5
multiple = a*b
multiple
# Out:
# 20

# %% [markdown]
# Division Operator : In Python (/) is the division operator. It is used to find the quotient when first operand is divided by the second.

# %%
# It will give you the quotient after complete division of given numbers
a = 11
b = 5
division = a/b
division
# Out:
# 2.2

# %% [markdown]
# Floor division : In Python (//) is used to conduct the floor division. It is used to find the floorof the quotient when first operand is divided by the second.

# %%
# It will give you the quotient without the decimal point value.
a = 11
b = 5
division = a//b
division
# Out:
# 2

# %% [markdown]
# Modulus Operator : In Python (%) is the modulus operator. It is used to find the remainder when first operand is divided by the second.

# %%
# It will give you the remainder value - after division.
a = 16
b = 5
modulus = a%b
modulus
# Out:
# 1

# %% [markdown]
# Exponentiation Operator : In Python, ** is the exponentiation operator. It is used to raise the first operand to power of second.

# %%
# It will give you the left side operand value with power of the right side operand value.
a = 3
b = 4
modulus = a**b
# 3 ** 2   =    3 * 3
modulus
# Out:
# 81

# %% [markdown]
# ###### All Arithmetic Operators:

# %% [markdown]
# ![Operators.JPG](attachment:Operators.JPG)

# %% [markdown]
# ### Relational Operators
#
# Comparison or Relational operators compares the values. It either returns True or False according to the condition.
#
# Relational operator compares the values of the operands on its either side and determines the relationship among them.

# %% [markdown]
# Greater than: True if the left operand is greater than the right
#
# Sign (>)

# %%
5 > 6
# Out:
# False

# %% [markdown]
# Less than: True if the left operand is less than the right
#
# Sign (<)

# %%
8 < 3
# Out:
# False

# %% [markdown]
# Equal to: True if both operands are equal
#
# Sign (==)

# %%
a = 8
b = a
b
# Out:
# 8

# %%
num = int(input("Please enter a number : "))

if num == 7:
    print('Enter number is seven:  ' , num)
else:
    print('Not seven : ', num)
# Out:
# Please enter a number : 8
# Not seven :  8

# %%
5==5
# Out:
# True

# %% [markdown]
# Not equal to – True if operands are not equal
#
# Sign (!=)

# %%
8 != 5
# Out:
# True

# %% [markdown]
# Greater than or equal to True if the left operand is greater than or equal to the right
#
# Sign(>=)

# %%
8>=8
# Out:
# True

# %% [markdown]
# Less than or equal to True if the left operand is less than or equal to the right
#
# Sign (<=)

# %%
8<=8
# Out:
# True

# %%
8<7
# Out:
# False

# %% [markdown]
# ![Operators%20Comprarison.JPG](attachment:Operators%20Comprarison.JPG)

# %% [markdown]
# ### Assignment Operators

# %% [markdown]
# Assignment operators are used to assign values to the variables.

# %%
x = 0
y = 8
z = 3

# %% [markdown]
# Assign value of right side of expression to left side operand
#
# =

# %%
x = y + z
x
# Out:
# 11

# %% [markdown]
# Add AND: Add right-side operand with left side operand and then assign to left operand
#
# +=

# %%
x = 6
y = int(input("Enter any value"))

print('X value before adding : ' , x)
x +=  y

print('x value after  : ' , x)
# Out:
# Enter any value9
# X value before adding :  6
# x value after  :  15

# %%
x = 6
y = int(input("Enter any value"))

print('X value before adding : ' , x)
c= x + y
print(c)
print('x value : ' , x)
# Out:
# Enter any value9
# X value before adding :  6
# 15
# x value :  6

# %%
x = 0
for i in range(21):
    x += i
print ('Sum of all number : ', x)
# Out:
# Sum of all number :  210

# %%
name = 'Sunil'
for i in name:
    print(i)
# Out:
# S
# u
# n
# i
# l

# %% [markdown]
# Subtract AND: Subtract right operand from left operand and then assign to left operand
#
# -=

# %%
x = 6
y = 8
print('X value before subtract : ' , x)
x -= y
print('X value after subtract : ' , x)
# Out:
# X value before subtract :  6
# X value after subtract :  -2

# %% [markdown]
# Multiply AND: Multiply right operand with left operand and then assign to left operand
#
# *=

# %%
x = 6
y = 8
print('X value before multiply : ' , x)
x *= y
print('X value after multiply : ' , x)
# Out:
# X value before multiply :  6
# X value after multiply :  48

# %% [markdown]
# Divide AND: Divide left operand with right operand and then assign to left operand
#
# /=

# %%
x = 6
y = 8
print('X value before multiply : ' , x)
x /= y
print('X value after multiply : ' , x)
# Out:
# X value before multiply :  6
# X value after multiply :  0.75

# %% [markdown]
# Modulus AND: Takes modulus using left and right operands and assign the result to left operand

# %%
x = 17
y = 6

x %= y
x
# 17 / 6
# Out:
# 5

# %%
# It will give you the remainder value - after division.
a = 16
b = 5
modulus = a%b
modulus

# %% [markdown]
# Divide(floor) AND: Divide left operand with right operand and then assign the value(floor) to left operand
#
# //=

# %%
x = 30
y = 12
print('X value before FLOOR AND : ' , x)


x //= y
print('X value after FLOOR AND : ' , x)
# Out:
# X value before FLOOR AND :  30
# X value after FLOOR AND :  2

# %% [markdown]
# Exponent AND: Calculate exponent(raise power) value using operands and assign value to left operand
#
# **=

# %%
x = 3
y = 2
z = x**y
print('This is an exponent value : ' , z)
x **=  y
x
# Out:
# This is an exponent value :  9
# 9

# %% [markdown]
# ### Logical Operators

# %% [markdown]
# There are three logical operators supported by Python.
#
# Logical operators perform Logical AND, Logical OR, and Logical NOT operations. It is used to combine conditional statements.

# %% [markdown]
# Logical AND: True if both the operands are true

# %% [markdown]
# Logical OR: True if either of the operands is true

# %% [markdown]
# Logical NOT: True if the operand is false

# %%
a = True
b = False

# %%
a and b

# %%
a or b

# %%
not a

# %% [markdown]
# ![operators2.JPG](attachment:operators2.JPG)

# %% [markdown]
# ### Membership Operators

# %% [markdown]
# in and not in are the membership operators; used to test whether a value or variable is in a sequence.

# %% [markdown]
# ###### in
# True if value is found in the sequence
#
# ###### not in
# True if value is not found in the sequence

# %%
x = 10
list = [10, 20, 30, 40, 50]
if (x not in list):
    print("x is NOT present in given list")
else:
    print("x is present in given list")
# Out:
# x is NOT present in given list

# %% [markdown]
# ### Bitwise Operators

# %% [markdown]
# Bitwise operators act on bits and perform the bit-by-bit operations. These are used to operate on binary numbers.

# %% [markdown]
# ![Operators3.JPG](attachment:Operators3.JPG)

# %%
# Examples of Bitwise operators
a = 10
b = 4

# %%
# Print bitwise AND operation
print(a & b)

# %%
# Print bitwise OR operation
print(a | b)

# %%
# Print bitwise NOT operation
print(~a)

# %%
# print bitwise XOR operation
print(a ^ b)

# %%
# print bitwise right shift operation
print(a >> 2)

# %%
# print bitwise left shift operation
print(a << 2)
# Out:
# 32

# %%
a = 6 + 8

# %%
7
# Out:
# 7

# %%
a
# Out:
# 14

# %%
-
# Out:
#   File "C:\Users\acer\AppData\Local\Temp/ipykernel_1572/476313318.py", line 1
#     -
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Expressions

# %% [markdown]
# An expression is defined as a combination of constants, variables and operators. An expression always evaluates to a value. A value or a standalone variable is also considered as an expression but a standalone operator is not an expression.

# %% [markdown]
# An expression is a combination of one or more operands, zero or more operators, and zero or more pairs of parentheses.
#
# There are three kinds of expressions:
#
# An arithmetic expression evaluates to a single arithmetic value.
#
# A character expression evaluates to a single value of type character.
#
# A logical or relational expression evaluates to a single logical value.

# %% [markdown]
# ###### Precedence of Operators

# %% [markdown]
# When an expression contains more than one operator, their precedence (order or hierarchy) determines which operator should be applied first.

# %% [markdown]
# ![Screenshot_20230129-180109-626.png](attachment:Screenshot_20230129-180109-626.png)

# %%
#a = 7 - * 27 / 3 (power 2) + 4

# %% [markdown]
# ###### Note:
# a) Parenthesis can be used to override the precedence of operators. The expression within () is evaluated first.
#
# b) For operators with equal precedence, the expression is evaluated from left to right.

# %%
#How will Python evaluate the following expression? 
(20 + 30) * 40
# Out:
# 2000

# %%
#How will Python evaluate the following expression? 
20 + 30 * 40
# Out:
# 1220

# %%
#How will the following expression be evaluated?
15.0 / 4.0 + (8 + 3.0)
# Out:
# 14.75

# %% [markdown]
# ## Some commonly used built-in functions in Python

# %% [markdown]
# ![operators%204.JPG](attachment:operators%204.JPG)

# %% [markdown]
# ### Range

# %% [markdown]
# The range() function returns a sequence of numbers, starting from 0 by default, and increments by 1 (by default), and stops before a specified number.

# %%
range(5)

# %% [markdown]
# range(start, stop, step)

# %% [markdown]
# Create a sequence of numbers from 3 to 5, and print each item in the sequence:

# %%
range(3,6)

# %%
for i in range(3,6):
    print (i)

# %% [markdown]
# ###### Create a sequence of numbers from 3 to 19, but increment by 2 instead of 1:

# %%
range(3,20,2)

# %%
for i in range(3,20,2):
    print(i)
